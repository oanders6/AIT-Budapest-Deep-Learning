# %% [markdown]
# <a href="https://colab.research.google.com/github/oanders6/AIT-Budapest-Deep-Learning/blob/main/Owen_Anderson_12_Anomaly_detection_AE_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Anomaly detection with autoencoders
#
# In this notebook we you have to create a fully-connected neural network based autoencoder in order to detect credit card frauds. In the dataset there are 492 labeled frauds and 284807 normal transactions. First, let's download the dataset and unpack it (original source of the dataset: https://www.kaggle.com/mlg-ulb/creditcardfraud - before downloading the data please read and accept the licence of the original datasource):

# %%
# !wget https://www.deeplearningoktatas.hu/downloads/Anomaly/creditcardfraud.zip
# Out:
# --2024-05-16 12:08:02--  https://www.deeplearningoktatas.hu/downloads/Anomaly/creditcardfraud.zip
# Resolving www.deeplearningoktatas.hu (www.deeplearningoktatas.hu)... 91.227.138.51
# Connecting to www.deeplearningoktatas.hu (www.deeplearningoktatas.hu)|91.227.138.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155632 (66M) [application/zip]
# Saving to: ‘creditcardfraud.zip.1’
#
# creditcardfraud.zip 100%[===================>]  65.95M  18.8MB/s    in 3.5s
#
# 2024-05-16 12:08:06 (18.8 MB/s) - ‘creditcardfraud.zip.1’ saved [69155632/69155632]

# %%
# %%capture
# !unzip creditcardfraud.zip

# %% [markdown]
# ## Imports
# Import the necessary modules:

# %%
import pandas as pd #
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import regularizers
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
np.random.seed(123)

# %% [markdown]
# ## Exercise 1: Reading and preparing the data
# Read the creditcard.csv into a Pandas Dataframe with the [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) function.

# %%
df = pd.read_csv('creditcard.csv')

# %%
print(df)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# As the next step, select all the columns of the dataframe for the input X, but the "Class" column. And select the "Class" column for output Y. Make sure that both X and Y are two dimensional Numpy arrays.
#
# Hint:
# * you can use df.loc to select rows and columns from a dataframe
# * you can get the Numpy array of a Pandas object with .values, eg. df['myfeature'].values

# %%
X = df.drop('Class', axis=1).values
Y = df['Class'].values

# %%
print("Shape of X:",X.shape)
print("Shape of Y:",Y.shape)
# Out:
# Shape of X: (284807, 30)
# Shape of Y: (284807,)

# %% [markdown]
# Let's standardize the data:

# %%
scaler = preprocessing.StandardScaler().fit(X)
X = scaler.transform(X)

# %% [markdown]
# ## Exercise 2: defining the autoencoder
# Let's define a model according to the following instructions:
# * the model's inputs and outputs should be the same as the number of X's features (columns)
# * the model should have 5 hidden layers, with 16-10-6-10-16 neurons in the hidden layers, respectively
# * all layers but the output should have tanh activation
# * the output layer should have linear activation

# %%
model = Sequential()

model.add(Dense(16, activation='tanh', input_shape=(30,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(6, activation='tanh'))
model.add(Dense(10, activation='tanh'))
model.add(Dense(16, activation='tanh'))
model.add(Dense(30, activation='linear'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 16)                496
#
#  dense_7 (Dense)             (None, 10)                170
#
#  dense_8 (Dense)             (None, 6)                 66
#
#  dense_9 (Dense)             (None, 10)                70
#
#  dense_10 (Dense)            (None, 16)                176
#
#  dense_11 (Dense)            (None, 30)                510
#
# =================================================================
# Total params: 1488 (5.81 KB)
# Trainable params: 1488 (5.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Exercise 3: define early stopping compile the model, and train it
# Please pay attention to the following details:
# * use EarlyStopping with patience 10 and this time monitor the training loss
# * do not define validation data
# * use mean squarred error loss function
# * both the input and output of the model should be X this time. (as we are "auto encoding" the input to the output)

# %%
patience = 10
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=patience)
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history= model.fit(X, X, epochs=100, batch_size=256, validation_split=0.2, callbacks=[es])
# Out:
# Epoch 1/100
# 891/891 [==============================] - 9s 7ms/step - loss: 0.4720 - val_loss: 0.5312
# Epoch 2/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4715 - val_loss: 0.5310
# Epoch 3/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4711 - val_loss: 0.5323
# Epoch 4/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4706 - val_loss: 0.5238
# Epoch 5/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4702 - val_loss: 0.5249
# Epoch 6/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4709 - val_loss: 0.5254
# Epoch 7/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4696 - val_loss: 0.5309
# Epoch 8/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4697 - val_loss: 0.5238
# Epoch 9/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4695 - val_loss: 0.5229
# Epoch 10/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4691 - val_loss: 0.5248
# Epoch 11/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4697 - val_loss: 0.5244
# Epoch 12/100
# 891/891 [==============================] - 7s 7ms/step - loss: 0.4689 - val_loss: 0.5373
# Epoch 13/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4689 - val_loss: 0.5204
# Epoch 14/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4690 - val_loss: 0.5309
# Epoch 15/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4688 - val_loss: 0.5204
# Epoch 16/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4681 - val_loss: 0.5262
# Epoch 17/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4691 - val_loss: 0.5211
# Epoch 18/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4683 - val_loss: 0.5189
# Epoch 19/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4683 - val_loss: 0.5212
# Epoch 20/100
# 891/891 [==============================] - 4s 5ms/step - loss: 0.4683 - val_loss: 0.5388
# Epoch 21/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4683 - val_loss: 0.5175
# Epoch 22/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4676 - val_loss: 0.5276
# Epoch 23/100
# 891/891 [==============================] - 6s 6ms/step - loss: 0.4679 - val_loss: 0.5279
# Epoch 24/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4676 - val_loss: 0.5210
# Epoch 25/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4673 - val_loss: 0.5218
# Epoch 26/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4680 - val_loss: 0.5228
# Epoch 27/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4672 - val_loss: 0.5191
# Epoch 28/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4676 - val_loss: 0.5207
# Epoch 29/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4670 - val_loss: 0.5233
# Epoch 30/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4669 - val_loss: 0.6138
# Epoch 31/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4677 - val_loss: 0.5198
# Epoch 32/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4667 - val_loss: 0.5327
# Epoch 33/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4675 - val_loss: 0.5178
# Epoch 34/100
# 891/891 [==============================] - 4s 5ms/step - loss: 0.4670 - val_loss: 0.5259
# Epoch 35/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4668 - val_loss: 0.5216
# Epoch 36/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4668 - val_loss: 0.5293
# Epoch 37/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4665 - val_loss: 0.5215
# Epoch 38/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4666 - val_loss: 0.5202
# Epoch 39/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4662 - val_loss: 0.5265
# Epoch 40/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4664 - val_loss: 0.5243
# Epoch 41/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4671 - val_loss: 0.5222
# Epoch 42/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4665 - val_loss: 0.5224
# Epoch 43/100
# 891/891 [==============================] - 6s 6ms/step - loss: 0.4662 - val_loss: 0.5547
# Epoch 44/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4662 - val_loss: 0.5354
# Epoch 45/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4658 - val_loss: 0.5726
# Epoch 46/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4663 - val_loss: 0.5228
# Epoch 47/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4657 - val_loss: 0.5308
# Epoch 48/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4658 - val_loss: 0.5225
# Epoch 49/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4665 - val_loss: 0.5208
# Epoch 50/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4654 - val_loss: 0.5242
# Epoch 51/100
# 891/891 [==============================] - 7s 7ms/step - loss: 0.4656 - val_loss: 0.5211
# Epoch 52/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4656 - val_loss: 0.5233
# Epoch 53/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4662 - val_loss: 0.5224
# Epoch 54/100
# 891/891 [==============================] - 7s 7ms/step - loss: 0.4657 - val_loss: 0.5191
# Epoch 55/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4654 - val_loss: 0.5282
# Epoch 56/100
# 891/891 [==============================] - 7s 7ms/step - loss: 0.4650 - val_loss: 0.5493
# Epoch 57/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4651 - val_loss: 0.5237
# Epoch 58/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4662 - val_loss: 0.5392
# Epoch 59/100
# 891/891 [==============================] - 7s 7ms/step - loss: 0.4652 - val_loss: 0.5413
# Epoch 60/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4654 - val_loss: 0.5299
# Epoch 61/100
# 891/891 [==============================] - 6s 6ms/step - loss: 0.4648 - val_loss: 0.5235
# Epoch 62/100
# 891/891 [==============================] - 6s 6ms/step - loss: 0.4650 - val_loss: 0.5297
# Epoch 63/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4653 - val_loss: 0.5391
# Epoch 64/100
# 891/891 [==============================] - 7s 7ms/step - loss: 0.4647 - val_loss: 0.5234
# Epoch 65/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4650 - val_loss: 0.5263
# Epoch 66/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4655 - val_loss: 0.5478
# Epoch 67/100
# 891/891 [==============================] - 7s 8ms/step - loss: 0.4646 - val_loss: 0.5264
# Epoch 68/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4650 - val_loss: 0.5257
# Epoch 69/100
# 891/891 [==============================] - 7s 7ms/step - loss: 0.4644 - val_loss: 0.5240
# Epoch 70/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4644 - val_loss: 0.5233
# Epoch 71/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4645 - val_loss: 0.5251
# Epoch 72/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4651 - val_loss: 0.5245
# Epoch 73/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4644 - val_loss: 0.5250
# Epoch 74/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4641 - val_loss: 0.5288
# Epoch 75/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4644 - val_loss: 0.5280
# Epoch 76/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4645 - val_loss: 0.5248
# Epoch 77/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4644 - val_loss: 0.5257
# Epoch 78/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4638 - val_loss: 0.5280
# Epoch 79/100
# 891/891 [==============================] - 4s 5ms/step - loss: 0.4636 - val_loss: 0.5340
# Epoch 80/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4637 - val_loss: 0.5346
# Epoch 81/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4643 - val_loss: 0.5297
# Epoch 82/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4644 - val_loss: 0.5388
# Epoch 83/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4638 - val_loss: 0.5302
# Epoch 84/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4635 - val_loss: 0.5269
# Epoch 85/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4638 - val_loss: 0.5281
# Epoch 86/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4642 - val_loss: 0.6174
# Epoch 87/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4638 - val_loss: 0.5347
# Epoch 88/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4630 - val_loss: 0.5261
# Epoch 89/100
# 891/891 [==============================] - 4s 5ms/step - loss: 0.4634 - val_loss: 0.5379
# Epoch 90/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4637 - val_loss: 0.5357
# Epoch 91/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4634 - val_loss: 0.5496
# Epoch 92/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4630 - val_loss: 0.5276
# Epoch 93/100
# 891/891 [==============================] - 5s 6ms/step - loss: 0.4634 - val_loss: 0.5411
# Epoch 94/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4637 - val_loss: 0.5269
# Epoch 95/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4629 - val_loss: 0.5293
# Epoch 96/100
# 891/891 [==============================] - 6s 6ms/step - loss: 0.4632 - val_loss: 0.5480
# Epoch 97/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4634 - val_loss: 0.5351
# Epoch 98/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4630 - val_loss: 0.5298
# Epoch 99/100
# 891/891 [==============================] - 6s 7ms/step - loss: 0.4627 - val_loss: 0.5268
# Epoch 100/100
# 891/891 [==============================] - 5s 5ms/step - loss: 0.4631 - val_loss: 0.5353

# %% [markdown]
# ## Results analysis
# After training is done, we make predictions for the complete dataset and inspect the reconstruction loss. Our assumption is that, higher reconstruction loss are more likely to belong to anomalies than lower reconstruciton loss.

# %%
preds = model.predict(X)
errs  = np.square(preds-X)
errs  = np.mean(errs,axis=1)
# Out:
# 8901/8901 [==============================] - 20s 2ms/step

# %%
plt.figure(figsize=(16,10))
rng = np.arange(len(errs))
colors = ['g','r'] # green: normal, red: anomaly
for i in [0,1]:
    plt.scatter(rng[(Y==i).reshape(-1)], errs[(Y==i).reshape(-1)], color=colors[i])

# %%
Y_cut    = Y[errs<10]
errs_cut = errs[errs<10]

# %%
plt.figure(figsize=(16,10))
rng = np.arange(len(errs_cut))
colors = ['g','r']
for i in [0,1]:
    plt.scatter(rng[(Y_cut==i).reshape(-1)], errs_cut[(Y_cut==i).reshape(-1)], color=colors[i])

# %% [markdown]
# ## Exercise 4: finding the right treshold
# Find a treshold that identifies at least 130 anomalies correctly with as small number of missclassifications of non-anomalies as possible.

# %%
treshold = 1.2
errs_filtered               = errs[errs>treshold]
Y_filtered                  = Y[errs>treshold]
errs_filtered_non_anomalies = errs[errs<=treshold]
Y_filtered_non_anomalies    = Y[errs<=treshold]

print("Anomalies in the dataset") # Y_filtered==1
print("   predicted as anomaly:", len(errs_filtered[Y_filtered==1]))
print("   predicted as non-anomaly: ", len(errs_filtered_non_anomalies[Y_filtered_non_anomalies==1]) )
print("Non-anomalies in the dataset") # Y_filtered ==0
print("   predicted as anomaly:", len(errs_filtered[Y_filtered==0]))
print("   predicted as non-anomaly:", len(errs_filtered_non_anomalies[Y_filtered_non_anomalies==0]) )
# Out:
# Anomalies in the dataset
#    predicted as anomaly: 358
#    predicted as non-anomaly:  134
# Non-anomalies in the dataset
#    predicted as anomaly: 12157
#    predicted as non-anomaly: 272158

# %% [markdown]
# We can also inspect the confusion matrix:

# %%
from sklearn.metrics import confusion_matrix
conf=confusion_matrix(Y, errs>treshold)
import seaborn as sns
sns.heatmap(conf, annot=True, vmax=8000, fmt="d")
# Out:
# <Axes: >
